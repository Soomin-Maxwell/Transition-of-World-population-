# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-0.60.0-py2.py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 744 kB/s eta 0:00:01     |▉                               | 174 kB 220 kB/s eta 0:00:32
# Collecting boto3
#   Downloading boto3-1.13.19-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 38.9 MB/s eta 0:00:01
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas>=0.21.0 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (1.18.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (0.3.1)
# Requirement already satisfied: cachetools>=4.0 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (4.1.0)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (7.0)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (3.12.0)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 5.5 MB/s eta 0:00:01
# Requirement already satisfied: watchdog in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (0.10.2)
# Collecting toml
#   Downloading toml-0.10.1-py2.py3-none-any.whl (19 kB)
# Collecting enum-compat
#   Downloading enum_compat-0.0.3-py3-none-any.whl (1.3 kB)
# Collecting botocore>=1.13.44
#   Downloading botocore-1.16.19-py2.py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 1.4 MB/s eta 0:00:01
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting validators
#   Downloading validators-0.15.0.tar.gz (27 kB)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (2.8.1)
# Collecting base58
#   Downloading base58-2.0.0-py3-none-any.whl (6.0 kB)
# Collecting tornado<6.0,>=5.0
#   Downloading tornado-5.1.1.tar.gz (516 kB)
#      |████████████████████████████████| 516 kB 322 kB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (2.22.0)
# Collecting altair>=3.2.0
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 28.9 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (20.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from streamlit) (7.0.0)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 5.4 MB/s eta 0:00:011
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.7/site-packages (from tzlocal->streamlit) (2019.3)
# Requirement already satisfied: traitlets>=4.3.2 in /opt/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (4.3.3)
# Requirement already satisfied: jinja2>=2.10.1 in /opt/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (2.11.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /opt/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.0->streamlit) (46.0.0.post20200309)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.0->streamlit) (1.14.0)
# Requirement already satisfied: pathtools>=0.1.1 in /opt/anaconda3/lib/python3.7/site-packages (from watchdog->streamlit) (0.1.2)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#      |████████████████████████████████| 547 kB 14.4 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /opt/anaconda3/lib/python3.7/site-packages (from botocore>=1.13.44->streamlit) (1.25.8)
# Requirement already satisfied: decorator>=3.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from validators->streamlit) (4.4.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->streamlit) (2.8)
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: entrypoints in /opt/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.10.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from packaging->streamlit) (2.4.6)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.7/site-packages (from jinja2>=2.10.1->pydeck>=0.1.dev5->streamlit) (1.1.1)
# Requirement already satisfied: jupyter-client in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: ipython>=5.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.12.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit) (19.3.0)
# Requirement already satisfied: pyzmq>=13 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (18.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.1)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.5.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair>=3.2.0->streamlit) (2.2.0)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.5.2)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.1.8)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: Send2Trash in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.1.0)
# Requirement already satisfied: testpath in /opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: blinker, validators, tornado
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13452 sha256=77886d229c05af50460d8eee15b12793a2614cdce78349fdaf55a013e3b79b54
#   Stored in directory: /Users/maxwell/Library/Caches/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.15.0-py3-none-any.whl size=18371 sha256=81615ddd26195b0f768dcefb4ccb6b9f75081eecc7b9b5ac46eedb0913fa88a9
#   Stored in directory: /Users/maxwell/Library/Caches/pip/wheels/ff/a1/08/0650ea8df7821ecd87760d16213b53dd23403927a69a388268
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-5.1.1-cp37-cp37m-macosx_10_9_x86_64.whl size=451785 sha256=65716fb03d7221c74d8fd3f32c7e53f393cd877105a982a4a9791cff6c3e13fc
#   Stored in directory: /Users/maxwell/Library/Caches/pip/wheels/83/91/4b/ee8ffb993d3372fc4129c52c9140792c118dda0373b41e7a8f
# Successfully built blinker validators tornado
# Installing collected packages: docutils, jmespath, botocore, s3transfer, boto3, tzlocal, blinker, toml, enum-compat, astor, validators, base58, tornado, altair, streamlit
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.3
#     Uninstalling tornado-6.0.3:
#       Successfully uninstalled tornado-6.0.3
# Successfully installed altair-4.1.0 astor-0.8.1 base58-2.0.0 blinker-1.4 boto3-1.13.19 botocore-1.16.19 docutils-0.15.2 enum-compat-0.0.3 jmespath-0.10.0 s3transfer-0.3.3 streamlit-0.60.0 toml-0.10.1 tornado-5.1.1 tzlocal-2.1 validators-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import pandas as pd
import geopandas as gpd
import pydeck as pdk
import json
import streamlit as st

# %%
# 국가,년도 별 인구 수 데이터 
df1 = pd.read_csv("projected-population-by-country.csv")
df1.head(10)
# Out:
#         Entity Code  Year  Population
# 0  Afghanistan  AFG  1800     3280000
# 1  Afghanistan  AFG  1801     3280000
# 2  Afghanistan  AFG  1802     3280000
# 3  Afghanistan  AFG  1803     3280000
# 4  Afghanistan  AFG  1804     3280000
# 5  Afghanistan  AFG  1805     3280000
# 6  Afghanistan  AFG  1806     3280000
# 7  Afghanistan  AFG  1807     3280000
# 8  Afghanistan  AFG  1808     3280000
# 9  Afghanistan  AFG  1809     3280000

# %%
# 국가별 위도, 경도 데이터 
df2 = "countries.csv"
df2 = pd.read_csv(df2)
df2.head(10)
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla
# 5      AL  41.153332  20.168331               Albania
# 6      AM  40.069099  45.038189               Armenia
# 7      AN  12.226079 -69.060087  Netherlands Antilles
# 8      AO -11.202692  17.873887                Angola
# 9      AQ -75.250973  -0.071389            Antarctica

# %%
# 두 데이터를 합침
merged = df2.merge(df1, left_on = 'name', right_on = 'Entity', how = 'left')

# 2020년 이전 데이터
merged = merged.loc[merged["Year"] < '2021', :] 

#year 값을 object -> value 로 변환 
merged['Year'] = merged['Year'].astype(int)
merged['Population'] = merged['Population'].astype(int)

#NAN을 string 으로 
merged.fillna('No data', inplace = True)
merged
# Out:
#       country   latitude  longitude      name    Entity Code  Year  Population
# 0          AD  42.546245   1.601554   Andorra   Andorra  AND  1800        2654
# 1          AD  42.546245   1.601554   Andorra   Andorra  AND  1801        2654
# 2          AD  42.546245   1.601554   Andorra   Andorra  AND  1802        2654
# 3          AD  42.546245   1.601554   Andorra   Andorra  AND  1803        2654
# 4          AD  42.546245   1.601554   Andorra   Andorra  AND  1804        2654
# ...       ...        ...        ...       ...       ...  ...   ...         ...
# 60010      ZW -19.015438  29.154857  Zimbabwe  Zimbabwe  ZWE  2016    14030000
# 60011      ZW -19.015438  29.154857  Zimbabwe  Zimbabwe  ZWE  2017    14237000
# 60012      ZW -19.015438  29.154857  Zimbabwe  Zimbabwe  ZWE  2018    14439000
# 60013      ZW -19.015438  29.154857  Zimbabwe  Zimbabwe  ZWE  2019    14645000
# 60014      ZW -19.015438  29.154857  Zimbabwe  Zimbabwe  ZWE  2020    14863000
#
# [43023 rows x 8 columns]

# %%
#인구를 0 ~ 1 사이의 값으로 변환시킨다. 
merged['normal'] = merged['Population'] / merged['Population'].max()

# Column country, entity, code 삭제 
merged.drop(["country", 'Entity', 'Code'], axis='columns', inplace=True)

#Read data to json
#merged_json = json.loads(merged.to_json())
#merged_json

# %%
initial_data = merged[merged['Year'] == 1800].to_dict(orient= 'records')
layer = pdk.Layer(
    "HeatmapLayer",
    initial_data,
    opacity=0.8,
    get_position=["longitude", "latitude"],
    aggregation="ADD",
    get_weight="normal",
    auto_highlight=True,
    pickable=True,
    get_radius=200)


center = [1.6015540000000001, 42.546245] 
view_state = pdk.ViewState( longitude=center[0], latitude=center[1], zoom=1) # Render 
r = pdk.Deck(
    layers=[layer], 
    initial_view_state=view_state ,
    views=[pdk.View(type='MapView', controller=None)],
    tooltip= {
        'html': '<b>Nation:</b> {nameValue}'
        "<br/> <b>Population:</b> {populationValue}",
        'style': {
            'color': 'white'
        }
    })
r.show()


# Widget 슬라이더 생성
import ipywidgets as widgets
from IPython.display import display
slider = widgets.IntSlider(1800, min=1800, max=2020, step=2)

# Widget에서 사용할 함수 정의 
def on_change(v):
    results = merged[merged['Year'] == slider.value].to_dict(orient='records')
    layer.data = results
    r.update()
        
# Deck과 슬라이더 연결
display(slider)
slider.observe(on_change)
r.show()

#슬라이더, 차트 연결 
#st.pydeck_chart(r)
#st.slider(r)
#r.to_html("test.html", open_browser=True, notebook_display=False)
# Out:
# IntSlider(value=1800, max=2020, min=1800, step=2)
# DeckGLWidget(json_input='{"initialViewState": {"latitude": 42.546245, "longitude": 1.6015540000000001, "zoom":…

# %%
#Read data to json
merged_json = json.loads(merged.to_json())

#Convert to str like object
json_data = json.dumps(merged_json)
